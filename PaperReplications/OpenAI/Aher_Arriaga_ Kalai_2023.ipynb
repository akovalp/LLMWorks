# %% [markdown]
# # Replication Code
#
# This work is a replication of the paper "Using Large Language Models to Simulate Multiple Humans and Replicate Human Subject Studies" by Gati Aher, Rosa I. Arriaga, and Adam Tauman Kalai (2023). In the original paper, the authors demonstrated results on four well-known psychology experiments using large language models (LLMs) to simulate human participants:
#
# 1. The Ultimatum Game - a behavioral economics game evaluating fairness and rationality. The LLM simulated responders deciding to accept or reject offers.
#
# 2. Garden Path Sentences - a psycholinguistics experiment judging the grammaticality of ambiguous sentences. The LLM simulated participants' judgments.
#
# 3. Milgram Shock Experiment - a famous social psychology obedience study. The LLM simulated administering shocks.
#
# 4. Wisdom of Crowds - an experiment evaluating collective intelligence and wisdom. The LLM simulated participants' numerical estimates.
#
# The code replication will focus on designing each experiment simulation in Python. The high-level steps are:
#
# 1. Define the experimental conditions and stimuli as input variables. For example, offer amounts for the Ultimatum Game.
#
# 2. Write prompt templates that incorporate the inputs. Prompts should provide clear instructions and examples.
#
# 3. Query the LLM using the prompts. The API call returns generated text.
#
# 4. Parse the generated text to record outcomes of interest. For example, extracting accept/reject decisions.
#
#
# The replication will apply this methodology to simulate each experiment with the GPT-3 API. While API costs limit large-scale runs, the code will demonstrate the approach and allow small-scale experiments to be reproduced. The prompts and outcome parsing will be designed to match the original paper as closely as possible.
#
# [https://arxiv.org/abs/2208.10264](Arxiv Link)

# %% [markdown]
# # Imports

# %%
import openai
import os
import random

openai.api_key = ""
print(openai.api_key)

# %% [markdown]
# ## Data Prep
# The original surnames data taken from the article

# %%
surnames_dict = {
    "American Indian": [
        "Begay", "Yazzie", "Benally", "Tsosie", "Nez", "Begaye", "Etsitty", "Becenti", 
        "Yellowhair", "Manygoats", "Wauneka", "Manuelito", "Apachito", "Bedonie", "Calabaza", 
        "Peshlakai", "Claw", "Roanhorse", "Goldtooth", "Etcitty", "Tsinnijinnie", "Notah", 
        "Clah", "Atcitty", "Twobulls", "Werito", "Hosteen", "Yellowman", "Attakai", "Bitsui", 
        "Delgarito", "Henio", "Goseyun", "Keams", "Secatero", "Declay", "Tapaha", "Beyale", 
        "Haskie", "Cayaditto", "Blackhorse", "Ethelbah", "Tsinnie", "Walkingeagle", "Altaha", 
        "Bitsilly", "Wassillie", "Benallie", "Smallcanyon", "Littledog", "Cosay", "Clitso", 
        "Tessay", "Secody", "Bigcrow", "Tabaha", "Chasinghawk", "Blueeyes", "Olanna", "Blackgoat", 
        "Cowboy", "Kanuho", "Shije", "Gishie", "Littlelight", "Laughing", "Whitehat", "Eriacho", 
        "Runningcrane", "Chinana", "Kameroff", "Spottedhorse", "Arcoren", "Whiteplume", "Dayzie", 
        "Spottedeagle", "Heavyrunner", "Standingrock", "Poorbear", "Ganadonegro", "Ayze", 
        "Whiteface", "Yepa", "Talayumptewa", "Madplume", "Bitsuie", "Tsethlikai", "Ahasteen", 
        "Dosela", "Birdinground", "Todacheenie", "Bitsie", "Todacheene", "Bullbear", "Lasiloo", 
        "Keyonnie", "Notafraid", "Colelay", "Kallestewa", "Littlewhiteman"
    ],
    "ANHOPI": [
        "Nguyen", "Kim", "Patel", "Tran", "Chen", "Li", "Le", "Wang", "Yang", "Pham", "Lin", "Liu", 
        "Huang", "Wu", "Zhang", "Shah", "Huynh", "Yu", "Choi", "Ho", "Kaur", "Vang", "Chung", "Truong", 
        "Phan", "Xiong", "Lim", "Vo", "Vu", "Lu", "Tang", "Cho", "Ngo", "Cheng", "Kang", "Tan", "Ng", 
        "Dang", "Do", "Ly", "Han", "Hoang", "Bui", "Sharma", "Chu", "Ma", "Xu", "Zheng", "Song", "Duong", 
        "Liang", "Sun", "Zhou", "Thao", "Zhao", "Shin", "Zhu", "Leung", "Hu", "Jiang", "Lai", "Gupta", 
        "Cheung", "Desai", "Oh", "Ha", "Cao", "Yi", "Hwang", "Lo", "Dinh", "Hsu", "Chau", "Yoon", "Luu", 
        "Trinh", "He", "Her", "Luong", "Mehta", "Moua", "Tam", "Ko", "Kwon", "Yoo", "Chiu", "Su", "Shen", 
        "Pan", "Dong", "Begum", "Gao", "Guo", "Chowdhury", "Vue", "Thai", "Jain", "Lor", "Yan", "Dao"
    ],
    "African American": [
        "Smalls", "Jeanbaptiste", "Diallo", "Kamara", "Pierrelouis", "Gadson", "Jeanlouis", "Bah", 
        "Desir", "Mensah", "Boykins", "Chery", "Jeanpierre", "Boateng", "Owusu", "Jama", "Jalloh", 
        "Sesay", "Ndiaye", "Abdullahi", "Wigfall", "Bienaime", "Diop", "Edouard", "Toure", "Grandberry", 
        "Fluellen", "Manigault", "Abebe", "Sow", "Traore", "Mondesir", "Okafor", "Bangura", "Louissaint", 
        "Cisse", "Osei", "Calixte", "Cephas", "Belizaire", "Fofana", "Koroma", "Conteh", "Straughter", 
        "Jeancharles", "Mwangi", "Kebede", "Mohamud", "Prioleau", "Yeboah", "Appiah", "Ajayi", "Asante", 
        "Filsaime", "Hardnett", "Hyppolite", "Saintlouis", "Jeanfrancois", "Ravenell", "Keita", "Bekele", 
        "Tadesse", "Mayweather", "Okeke", "Asare", "Ulysse", "Saintil", "Tesfaye", "Jeanjacques", "Ojo", 
        "Nwosu", "Okoro", "Fobbs", "Kidane", "Petitfrere", "Yohannes", "Warsame", "Lawal", "Desta", 
        "Veasley", "Addo", "Leaks", "Gueye", "Mekonnen", "Stfleur", "Balogun", "Adjei", "Opoku", "Coaxum", 
        "Vassell", "Prophete", "Lesane", "Metellus", "Exantus", "Hailu", "Dorvil", "Frimpong", "Berhane", 
        "Njoroge", "Beyene"
    ],
    "Latino": [
        "Garcia", "Rodriguez", "Martinez", "Hernandez", "Lopez", "Gonzalez", "Perez", "Sanchez", 
        "Ramirez", "Torres", "Flores", "Rivera", "Gomez", "Diaz", "Morales", "Gutierrez", "Ortiz", 
        "Chavez", "Ruiz", "Alvarez", "Castillo", "Jimenez", "Vasquez", "Moreno", "Herrera", "Medina", 
        "Aguilar", "Vargas", "Guzman", "Mendez", "Munoz", "Salazar", "Garza", "Soto", "Vazquez", 
        "Alvarado", "Delgado", "Pena", "Contreras", "Sandoval", "Guerrero", "Rios", "Estrada", "Ortega", 
        "Nunez", "Maldonado", "Dominguez", "Vega", "Espinoza", "Rojas", "Marquez", "Padilla", "Mejia", 
        "Juarez", "Figueroa", "Avila", "Molina", "Campos", "Ayala", "Carrillo", "Cabrera", "Lara", "Robles", 
        "Cervantes", "Solis", "Salinas", "Fuentes", "Velasquez", "Aguirre", "Ochoa", "Cardenas", "Calderon", 
        "Rivas", "Serrano", "Rosales", "Castaneda", "Gallegos", "Ibarra", "Suarez", "Orozco", "Salas", 
        "Escobar", "Velazquez", "Macias", "Zamora", "Villarreal", "Barrera", "Pineda", "Santana", "Trevino", 
        "Lozano", "Rangel", "Arias", "Mora", "Valenzuela", "Zuniga", "Melendez", "Galvan", "Velez", "Meza"
    ],
    "Caucasian": [
        "Olson", "Snyder", "Wagner", "Meyer", "Schmidt", "Ryan", "Hansen", "Hoffman", "Johnston", "Larson", 
        "Carlson", "Obrien", "Jensen", "Hanson", "Weber", "Walsh", "Schultz", "Schneider", "Keller", "Beck", 
        "Schwartz", "Becker", "Wolfe", "Zimmerman", "Mccarthy", "Erickson", "Klein", "Oconnor", "Swanson", 
        "Christensen", "Fischer", "Wolf", "Gallagher", "Schroeder", "Parsons", "Bauer", "Mueller", "Hartman", 
        "Kramer", "Flynn", "Owen", "Shaffer", "Hess", "Olsen", "Petersen", "Roth", "Hoover", "Weiss", "Decker", 
        "Yoder", "Larsen", "Sweeney", "Foley", "Hensley", "Huffman", "Cline", "Oneill", "Koch", "Brennan", 
        "Berg", "Russo", "Macdonald", "Kline", "Jacobson", "Berger", "Blankenship", "Bartlett", "Odonnell", 
        "Stein", "Stout", "Sexton", "Nielsen", "Howe", "Morse", "Knapp", "Herman", "Stark", "Hebert", 
        "Schaefer", "Reilly", "Conrad", "Donovan", "Mahoney", "Hahn", "Peck", "Boyle", "Hurley", "Mayer", 
        "Mcmahon", "Case", "Duffy", "Friedman", "Fry", "Dougherty", "Crane", "Huber", "Moyer", "Krueger", 
        "Rasmussen", "Brandt"
    ]
}

# %% [markdown]
# # Code

# %% [markdown]
# ## The Ultimatum Game TE
#
# Two players are matched and assigned the roles of proposer and responder. <br>
# **Proposer:** given an amount of money and has to decide how to split it between himself and the responder. <br>
# **Responder:** If the responder accepts the take-it-or-leave-it proposal, both players receive their designated shares, otherwise both players receive nothing <br>
# **Aim:**  Experiments on the Ultimatum Game reveal an anomaly in economic decision making: since the responder will receive nothing if they reject, the responder’s dominant strategy to maximize monetary gain is to always accept; in practice, responders typically reject unfair proposals.
#
# ### Inputs
# 1. an integer offer in {0, 1, . . . , 10}
# 2. the name of the proposer
# 3. the name of the responder
#
# The offer corresponds to an initial endowment fixed at $10 and eleven possible offers.

# %% [markdown]
# ### Name Shufler

# %% [markdown]
#  Generates pairs of surnames with associated titles and random scores. It creates variations of titles (Mr. and Ms.) for each surname pair and associates them with random scores.

# %%
def generate_pairs(surnames_dict):
    # Flatten the dictionary to get a list of all surnames
    all_surnames = []
    for names in surnames_dict.values():
        all_surnames.extend(names)
    random.shuffle(all_surnames)
    pairs = []
    for surname in all_surnames:
        # Get the racial group of the current surname
        current_group = next(
            (group for group, names in surnames_dict.items() if surname in names), None)

        # For each racial group, select one surname for pairing
        for group, names in surnames_dict.items():
            paired_surname = random.choice(names)

            # Create 2x2 combinations of "Mr." and "Ms." titles and combine them with surnames
            pairs.append(
                (f"Mr. {surname} , Mr. {paired_surname}", random.randint(0, 10)))
            pairs.append(
                (f"Mr. {surname} , Ms. {paired_surname}", random.randint(0, 10)))
            pairs.append(
                (f"Ms. {surname} , Mr. {paired_surname}", random.randint(0, 10)))
            pairs.append(
                (f"Ms. {surname} , Ms. {paired_surname}", random.randint(0, 10)))

    # Return the first 10,000 pairs
    enumerated_pairs = list(enumerate(pairs, start=1))
    return enumerated_pairs[:10000]
pairs = generate_pairs(surnames_dict)
pairs = pairs[:2500]

# %% [markdown]
# Lets take a look at our pairs

# %%
for index, (pair_number, (pair_string, random_number)) in enumerate(pairs, start=1):
    first_name, second_name = [name.strip() for name in pair_string.split(",")]
    first_name_gender, first_surname = first_name.split(".")
    second_name_gender, second_surname = second_name.split(".")
    first_name_ethnicity = next((group for group, names in surnames_dict.items(
    ) if first_surname.strip() in names), None)
    second_name_ethnicity = next((group for group, names in surnames_dict.items(
    ) if second_surname.strip() in names), None)
    print(f"Pair {pair_number}:")
    print("Name of the proposer:", first_name)
    print("Proposer gender:", first_name_gender)
    print("Ethnicity of the proposer:", first_name_ethnicity)
    print("Name of the responder:", second_name)
    print("Responder gender:", second_name_gender)
    print("Ethnicity of the responder:", second_name_ethnicity)
    print("-" * 45)
# Out:
# Pair 1:
# Name of the proposer: Mr. Berger
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Laughing
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 2:
# Name of the proposer: Mr. Berger
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Laughing
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 3:
# Name of the proposer: Ms. Berger
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Laughing
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 4:
# Name of the proposer: Ms. Berger
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Laughing
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 5:
# Name of the proposer: Mr. Berger
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Kaur
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 6:
# Name of the proposer: Mr. Berger
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Kaur
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 7:
# Name of the proposer: Ms. Berger
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Kaur
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 8:
# Name of the proposer: Ms. Berger
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Kaur
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 9:
# Name of the proposer: Mr. Berger
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Ajayi
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 10:
# Name of the proposer: Mr. Berger
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Ajayi
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 11:
# Name of the proposer: Ms. Berger
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Ajayi
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 12:
# Name of the proposer: Ms. Berger
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Ajayi
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 13:
# Name of the proposer: Mr. Berger
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Carrillo
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 14:
# Name of the proposer: Mr. Berger
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Carrillo
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 15:
# Name of the proposer: Ms. Berger
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Carrillo
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 16:
# Name of the proposer: Ms. Berger
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Carrillo
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 17:
# Name of the proposer: Mr. Berger
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Bauer
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 18:
# Name of the proposer: Mr. Berger
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Bauer
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 19:
# Name of the proposer: Ms. Berger
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Bauer
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 20:
# Name of the proposer: Ms. Berger
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Bauer
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 21:
# Name of the proposer: Mr. Huang
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Secatero
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 22:
# Name of the proposer: Mr. Huang
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Secatero
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 23:
# Name of the proposer: Ms. Huang
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Secatero
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 24:
# Name of the proposer: Ms. Huang
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Secatero
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 25:
# Name of the proposer: Mr. Huang
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Trinh
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 26:
# Name of the proposer: Mr. Huang
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Trinh
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 27:
# Name of the proposer: Ms. Huang
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Trinh
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 28:
# Name of the proposer: Ms. Huang
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Trinh
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 29:
# Name of the proposer: Mr. Huang
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Ndiaye
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 30:
# Name of the proposer: Mr. Huang
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Ndiaye
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 31:
# Name of the proposer: Ms. Huang
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Ndiaye
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 32:
# Name of the proposer: Ms. Huang
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Ndiaye
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 33:
# Name of the proposer: Mr. Huang
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Torres
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 34:
# Name of the proposer: Mr. Huang
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Torres
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 35:
# Name of the proposer: Ms. Huang
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Torres
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 36:
# Name of the proposer: Ms. Huang
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Torres
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 37:
# Name of the proposer: Mr. Huang
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Crane
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 38:
# Name of the proposer: Mr. Huang
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Crane
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 39:
# Name of the proposer: Ms. Huang
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Crane
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 40:
# Name of the proposer: Ms. Huang
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Crane
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 41:
# Name of the proposer: Mr. Sow
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Notafraid
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 42:
# Name of the proposer: Mr. Sow
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Notafraid
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 43:
# Name of the proposer: Ms. Sow
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Notafraid
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 44:
# Name of the proposer: Ms. Sow
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Notafraid
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 45:
# Name of the proposer: Mr. Sow
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Yang
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 46:
# Name of the proposer: Mr. Sow
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Yang
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 47:
# Name of the proposer: Ms. Sow
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Yang
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 48:
# Name of the proposer: Ms. Sow
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Yang
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 49:
# Name of the proposer: Mr. Sow
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Kebede
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 50:
# Name of the proposer: Mr. Sow
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Kebede
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 51:
# Name of the proposer: Ms. Sow
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Kebede
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 52:
# Name of the proposer: Ms. Sow
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Kebede
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 53:
# Name of the proposer: Mr. Sow
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Nunez
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 54:
# Name of the proposer: Mr. Sow
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Nunez
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 55:
# Name of the proposer: Ms. Sow
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Nunez
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 56:
# Name of the proposer: Ms. Sow
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Nunez
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 57:
# Name of the proposer: Mr. Sow
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Stein
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 58:
# Name of the proposer: Mr. Sow
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Stein
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 59:
# Name of the proposer: Ms. Sow
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Stein
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 60:
# Name of the proposer: Ms. Sow
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Stein
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 61:
# Name of the proposer: Mr. Hahn
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Wauneka
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 62:
# Name of the proposer: Mr. Hahn
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Wauneka
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 63:
# Name of the proposer: Ms. Hahn
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Wauneka
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 64:
# Name of the proposer: Ms. Hahn
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Wauneka
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 65:
# Name of the proposer: Mr. Hahn
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Ho
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 66:
# Name of the proposer: Mr. Hahn
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Ho
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 67:
# Name of the proposer: Ms. Hahn
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Ho
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 68:
# Name of the proposer: Ms. Hahn
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Ho
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 69:
# Name of the proposer: Mr. Hahn
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Berhane
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 70:
# Name of the proposer: Mr. Hahn
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Berhane
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 71:
# Name of the proposer: Ms. Hahn
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Berhane
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 72:
# Name of the proposer: Ms. Hahn
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Berhane
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 73:
# Name of the proposer: Mr. Hahn
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Pena
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 74:
# Name of the proposer: Mr. Hahn
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Pena
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 75:
# Name of the proposer: Ms. Hahn
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Pena
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 76:
# Name of the proposer: Ms. Hahn
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Pena
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 77:
# Name of the proposer: Mr. Hahn
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Hurley
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 78:
# Name of the proposer: Mr. Hahn
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Hurley
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 79:
# Name of the proposer: Ms. Hahn
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Hurley
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 80:
# Name of the proposer: Ms. Hahn
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Hurley
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 81:
# Name of the proposer: Mr. Lawal
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Tessay
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 82:
# Name of the proposer: Mr. Lawal
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Tessay
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 83:
# Name of the proposer: Ms. Lawal
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Tessay
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 84:
# Name of the proposer: Ms. Lawal
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Tessay
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 85:
# Name of the proposer: Mr. Lawal
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Duong
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 86:
# Name of the proposer: Mr. Lawal
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Duong
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 87:
# Name of the proposer: Ms. Lawal
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Duong
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 88:
# Name of the proposer: Ms. Lawal
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Duong
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 89:
# Name of the proposer: Mr. Lawal
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Kebede
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 90:
# Name of the proposer: Mr. Lawal
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Kebede
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 91:
# Name of the proposer: Ms. Lawal
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Kebede
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 92:
# Name of the proposer: Ms. Lawal
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Kebede
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 93:
# Name of the proposer: Mr. Lawal
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Calderon
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 94:
# Name of the proposer: Mr. Lawal
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Calderon
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 95:
# Name of the proposer: Ms. Lawal
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Calderon
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 96:
# Name of the proposer: Ms. Lawal
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Calderon
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 97:
# Name of the proposer: Mr. Lawal
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Russo
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 98:
# Name of the proposer: Mr. Lawal
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Russo
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 99:
# Name of the proposer: Ms. Lawal
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Russo
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 100:
# Name of the proposer: Ms. Lawal
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Russo
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 101:
# Name of the proposer: Mr. Bedonie
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Etcitty
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 102:
# Name of the proposer: Mr. Bedonie
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Etcitty
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 103:
# Name of the proposer: Ms. Bedonie
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Etcitty
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 104:
# Name of the proposer: Ms. Bedonie
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Etcitty
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 105:
# Name of the proposer: Mr. Bedonie
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Yu
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 106:
# Name of the proposer: Mr. Bedonie
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Yu
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 107:
# Name of the proposer: Ms. Bedonie
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Yu
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 108:
# Name of the proposer: Ms. Bedonie
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Yu
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 109:
# Name of the proposer: Mr. Bedonie
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Hardnett
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 110:
# Name of the proposer: Mr. Bedonie
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Hardnett
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 111:
# Name of the proposer: Ms. Bedonie
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Hardnett
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 112:
# Name of the proposer: Ms. Bedonie
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Hardnett
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 113:
# Name of the proposer: Mr. Bedonie
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Sandoval
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 114:
# Name of the proposer: Mr. Bedonie
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Sandoval
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 115:
# Name of the proposer: Ms. Bedonie
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Sandoval
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 116:
# Name of the proposer: Ms. Bedonie
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Sandoval
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 117:
# Name of the proposer: Mr. Bedonie
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Dougherty
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 118:
# Name of the proposer: Mr. Bedonie
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Dougherty
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 119:
# Name of the proposer: Ms. Bedonie
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Dougherty
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 120:
# Name of the proposer: Ms. Bedonie
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Dougherty
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 121:
# Name of the proposer: Mr. Vega
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Benallie
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 122:
# Name of the proposer: Mr. Vega
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Benallie
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 123:
# Name of the proposer: Ms. Vega
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Benallie
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 124:
# Name of the proposer: Ms. Vega
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Benallie
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 125:
# Name of the proposer: Mr. Vega
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Trinh
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 126:
# Name of the proposer: Mr. Vega
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Trinh
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 127:
# Name of the proposer: Ms. Vega
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Trinh
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 128:
# Name of the proposer: Ms. Vega
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Trinh
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 129:
# Name of the proposer: Mr. Vega
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Sow
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 130:
# Name of the proposer: Mr. Vega
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Sow
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 131:
# Name of the proposer: Ms. Vega
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Sow
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 132:
# Name of the proposer: Ms. Vega
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Sow
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 133:
# Name of the proposer: Mr. Vega
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Lopez
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 134:
# Name of the proposer: Mr. Vega
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Lopez
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 135:
# Name of the proposer: Ms. Vega
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Lopez
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 136:
# Name of the proposer: Ms. Vega
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Lopez
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 137:
# Name of the proposer: Mr. Vega
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Fischer
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 138:
# Name of the proposer: Mr. Vega
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Fischer
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 139:
# Name of the proposer: Ms. Vega
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Fischer
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 140:
# Name of the proposer: Ms. Vega
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Fischer
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 141:
# Name of the proposer: Mr. Hurley
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Wauneka
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 142:
# Name of the proposer: Mr. Hurley
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Wauneka
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 143:
# Name of the proposer: Ms. Hurley
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Wauneka
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 144:
# Name of the proposer: Ms. Hurley
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Wauneka
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 145:
# Name of the proposer: Mr. Hurley
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Zhang
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 146:
# Name of the proposer: Mr. Hurley
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Zhang
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 147:
# Name of the proposer: Ms. Hurley
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Zhang
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 148:
# Name of the proposer: Ms. Hurley
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Zhang
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 149:
# Name of the proposer: Mr. Hurley
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Saintlouis
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 150:
# Name of the proposer: Mr. Hurley
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Saintlouis
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 151:
# Name of the proposer: Ms. Hurley
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Saintlouis
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 152:
# Name of the proposer: Ms. Hurley
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Saintlouis
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 153:
# Name of the proposer: Mr. Hurley
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Guerrero
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 154:
# Name of the proposer: Mr. Hurley
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Guerrero
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 155:
# Name of the proposer: Ms. Hurley
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Guerrero
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 156:
# Name of the proposer: Ms. Hurley
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Guerrero
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 157:
# Name of the proposer: Mr. Hurley
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Wolfe
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 158:
# Name of the proposer: Mr. Hurley
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Wolfe
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 159:
# Name of the proposer: Ms. Hurley
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Wolfe
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 160:
# Name of the proposer: Ms. Hurley
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Wolfe
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 161:
# Name of the proposer: Mr. Morales
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Secatero
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 162:
# Name of the proposer: Mr. Morales
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Secatero
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 163:
# Name of the proposer: Ms. Morales
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Secatero
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 164:
# Name of the proposer: Ms. Morales
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Secatero
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 165:
# Name of the proposer: Mr. Morales
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Sun
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 166:
# Name of the proposer: Mr. Morales
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Sun
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 167:
# Name of the proposer: Ms. Morales
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Sun
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 168:
# Name of the proposer: Ms. Morales
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Sun
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 169:
# Name of the proposer: Mr. Morales
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Prophete
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 170:
# Name of the proposer: Mr. Morales
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Prophete
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 171:
# Name of the proposer: Ms. Morales
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Prophete
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 172:
# Name of the proposer: Ms. Morales
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Prophete
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 173:
# Name of the proposer: Mr. Morales
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Martinez
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 174:
# Name of the proposer: Mr. Morales
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Martinez
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 175:
# Name of the proposer: Ms. Morales
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Martinez
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 176:
# Name of the proposer: Ms. Morales
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Martinez
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 177:
# Name of the proposer: Mr. Morales
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Schmidt
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 178:
# Name of the proposer: Mr. Morales
# Proposer gender: Mr
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Schmidt
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 179:
# Name of the proposer: Ms. Morales
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Mr. Schmidt
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 180:
# Name of the proposer: Ms. Morales
# Proposer gender: Ms
# Ethnicity of the proposer: Latino
# Name of the responder: Ms. Schmidt
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 181:
# Name of the proposer: Mr. Luu
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Tapaha
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 182:
# Name of the proposer: Mr. Luu
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Tapaha
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 183:
# Name of the proposer: Ms. Luu
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Tapaha
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 184:
# Name of the proposer: Ms. Luu
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Tapaha
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 185:
# Name of the proposer: Mr. Luu
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Xu
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 186:
# Name of the proposer: Mr. Luu
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Xu
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 187:
# Name of the proposer: Ms. Luu
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Xu
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 188:
# Name of the proposer: Ms. Luu
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Xu
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 189:
# Name of the proposer: Mr. Luu
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Kebede
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 190:
# Name of the proposer: Mr. Luu
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Kebede
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 191:
# Name of the proposer: Ms. Luu
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Kebede
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 192:
# Name of the proposer: Ms. Luu
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Kebede
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 193:
# Name of the proposer: Mr. Luu
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Guzman
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 194:
# Name of the proposer: Mr. Luu
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Guzman
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 195:
# Name of the proposer: Ms. Luu
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Guzman
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 196:
# Name of the proposer: Ms. Luu
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Guzman
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 197:
# Name of the proposer: Mr. Luu
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Krueger
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 198:
# Name of the proposer: Mr. Luu
# Proposer gender: Mr
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Krueger
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 199:
# Name of the proposer: Ms. Luu
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Mr. Krueger
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 200:
# Name of the proposer: Ms. Luu
# Proposer gender: Ms
# Ethnicity of the proposer: ANHOPI
# Name of the responder: Ms. Krueger
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 201:
# Name of the proposer: Mr. Warsame
# ...
# Pair 2437:
# Name of the proposer: Mr. Swanson
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Sweeney
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2438:
# Name of the proposer: Mr. Swanson
# Proposer gender: Mr
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Sweeney
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2439:
# Name of the proposer: Ms. Swanson
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Mr. Sweeney
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2440:
# Name of the proposer: Ms. Swanson
# Proposer gender: Ms
# Ethnicity of the proposer: Caucasian
# Name of the responder: Ms. Sweeney
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2441:
# Name of the proposer: Mr. Mondesir
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Gishie
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 2442:
# Name of the proposer: Mr. Mondesir
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Gishie
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 2443:
# Name of the proposer: Ms. Mondesir
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Gishie
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 2444:
# Name of the proposer: Ms. Mondesir
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Gishie
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 2445:
# Name of the proposer: Mr. Mondesir
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Hu
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 2446:
# Name of the proposer: Mr. Mondesir
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Hu
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 2447:
# Name of the proposer: Ms. Mondesir
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Hu
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 2448:
# Name of the proposer: Ms. Mondesir
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Hu
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 2449:
# Name of the proposer: Mr. Mondesir
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Edouard
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 2450:
# Name of the proposer: Mr. Mondesir
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Edouard
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 2451:
# Name of the proposer: Ms. Mondesir
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Edouard
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 2452:
# Name of the proposer: Ms. Mondesir
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Edouard
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 2453:
# Name of the proposer: Mr. Mondesir
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Ayala
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 2454:
# Name of the proposer: Mr. Mondesir
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Ayala
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 2455:
# Name of the proposer: Ms. Mondesir
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Ayala
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 2456:
# Name of the proposer: Ms. Mondesir
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Ayala
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 2457:
# Name of the proposer: Mr. Mondesir
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Hansen
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2458:
# Name of the proposer: Mr. Mondesir
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Hansen
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2459:
# Name of the proposer: Ms. Mondesir
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Hansen
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2460:
# Name of the proposer: Ms. Mondesir
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Hansen
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2461:
# Name of the proposer: Mr. Todacheene
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Keyonnie
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 2462:
# Name of the proposer: Mr. Todacheene
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Keyonnie
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 2463:
# Name of the proposer: Ms. Todacheene
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Keyonnie
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 2464:
# Name of the proposer: Ms. Todacheene
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Keyonnie
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 2465:
# Name of the proposer: Mr. Todacheene
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Jiang
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 2466:
# Name of the proposer: Mr. Todacheene
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Jiang
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 2467:
# Name of the proposer: Ms. Todacheene
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Jiang
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 2468:
# Name of the proposer: Ms. Todacheene
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Jiang
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 2469:
# Name of the proposer: Mr. Todacheene
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Cephas
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 2470:
# Name of the proposer: Mr. Todacheene
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Cephas
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 2471:
# Name of the proposer: Ms. Todacheene
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Cephas
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 2472:
# Name of the proposer: Ms. Todacheene
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Cephas
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 2473:
# Name of the proposer: Mr. Todacheene
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Villarreal
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 2474:
# Name of the proposer: Mr. Todacheene
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Villarreal
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 2475:
# Name of the proposer: Ms. Todacheene
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Villarreal
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 2476:
# Name of the proposer: Ms. Todacheene
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Villarreal
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 2477:
# Name of the proposer: Mr. Todacheene
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Beck
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2478:
# Name of the proposer: Mr. Todacheene
# Proposer gender: Mr
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Beck
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2479:
# Name of the proposer: Ms. Todacheene
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Mr. Beck
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2480:
# Name of the proposer: Ms. Todacheene
# Proposer gender: Ms
# Ethnicity of the proposer: American Indian
# Name of the responder: Ms. Beck
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2481:
# Name of the proposer: Mr. Hailu
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Madplume
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 2482:
# Name of the proposer: Mr. Hailu
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Madplume
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 2483:
# Name of the proposer: Ms. Hailu
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Madplume
# Responder gender: Mr
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 2484:
# Name of the proposer: Ms. Hailu
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Madplume
# Responder gender: Ms
# Ethnicity of the responder: American Indian
# ---------------------------------------------
# Pair 2485:
# Name of the proposer: Mr. Hailu
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Liang
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 2486:
# Name of the proposer: Mr. Hailu
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Liang
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 2487:
# Name of the proposer: Ms. Hailu
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Liang
# Responder gender: Mr
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 2488:
# Name of the proposer: Ms. Hailu
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Liang
# Responder gender: Ms
# Ethnicity of the responder: ANHOPI
# ---------------------------------------------
# Pair 2489:
# Name of the proposer: Mr. Hailu
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Metellus
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 2490:
# Name of the proposer: Mr. Hailu
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Metellus
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 2491:
# Name of the proposer: Ms. Hailu
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Metellus
# Responder gender: Mr
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 2492:
# Name of the proposer: Ms. Hailu
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Metellus
# Responder gender: Ms
# Ethnicity of the responder: African American
# ---------------------------------------------
# Pair 2493:
# Name of the proposer: Mr. Hailu
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Robles
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 2494:
# Name of the proposer: Mr. Hailu
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Robles
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 2495:
# Name of the proposer: Ms. Hailu
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Robles
# Responder gender: Mr
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 2496:
# Name of the proposer: Ms. Hailu
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Robles
# Responder gender: Ms
# Ethnicity of the responder: Latino
# ---------------------------------------------
# Pair 2497:
# Name of the proposer: Mr. Hailu
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Schaefer
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2498:
# Name of the proposer: Mr. Hailu
# Proposer gender: Mr
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Schaefer
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2499:
# Name of the proposer: Ms. Hailu
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Mr. Schaefer
# Responder gender: Mr
# Ethnicity of the responder: Caucasian
# ---------------------------------------------
# Pair 2500:
# Name of the proposer: Ms. Hailu
# Proposer gender: Ms
# Ethnicity of the proposer: African American
# Name of the responder: Ms. Schaefer
# Responder gender: Ms
# Ethnicity of the responder: Caucasian
# ---------------------------------------------

# %% [markdown]
# Using gpt-3.5-turbo-0613 model update to replicate the process since this update introduces the function calling capability for the model and makes it much easier to parse well structured outputs from the model

# %%
import openai

def deal(first_name, second_name, money, basemoney):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-0613",
        messages=[
            {
                "role": "system",
                "content": "You are helpfull asistant that will give only one word answers that who will analyze the following scenario and consider what individuals do in this situation and will give a definitive answer as accepted or rejected."
            },
            {
                "role": "user",
                "content": f"""
                In the following scenario, {first_name} had to decide whether to accept or reject the proposal.
                Scenario: {second_name} is given {basemoney}. {second_name} will propose how to split the money between him/her self and {first_name}. Then {first_name} will decide whether to accept or reject {second_name}'s proposal. If {first_name} accepts, then {second_name} and {first_name} get the money as they agreed to split. if {first_name} rejects, then {second_name} and {first_name} both receive nothing. 
                The offer: {second_name} proposes to give {first_name} {offer} and keep {basemoney - offer} for him/her self.
                Answer: {first_name} decides to: 
                """
            },
        ],
        temperature=0,
    )
    
   
    print(f"The proposer is: {first_name}")
    print(f"The responder is: {second_name}")
    print(f"The offered amount is {offer}")

    return response 

# Assuming you have defined debug_pairs somewhere
for pair_number, (pair_string, random_number) in pairs:
    names = pair_string.split(",")
    first_name = names[0].strip()
    second_name = names[1].strip()
    basemoney = 10
    offer = 10 - random_number

    response = deal(first_name, second_names, money, basemoney)
    answer = response['choices'][0]['message']['content']
    print(f"The {first_name} would {answer} the offer.")
    print("-*-" * 20)

# %% [markdown]
# ## Garden Path TE
# A garden path sentence is a grammatical sentence that seems ungrammatical because it contains a word or phrase that can be interpreted in multiple ways. For example, a human reading “While Anna dressed the baby that was small and cute spit up on the bed” may initially believe that Anna is dressing the baby but upon re-parsing the sentence understand that Anna is dressing herself. Psycholinguists use garden path sentences to study the variability in the difficulty of comprehending relative clause constructions and other effects.
#
# ### Inputs
# **Garden Path Sentences:**
# - 12 Optionally Transitive (OT) garden path sentences.
# - 12 Reflexive Absolute Transitive (RAT) garden path sentences.
# - Total of 24 garden path sentences.
#
# **Control Sentences:**
# - 24 control sentences derived from the garden path sentences by adding a disambiguating comma after the verb of the subordinate clause.
#
# **Names Set**
# - A set of 1000 names
#
# **Novel Garden Path Sentences**
# - Set of 12 RAT garden path sentences authored by the researchers.
# - Set of 12 OT garden path sentences authored by the researchers.

# %% [markdown]
# The code down below will be used for name selection from the data set In the Garden Path Turing Experiment simulation, the authors selected names from a pool of 1000 first name-surname combinations

# %%
sentences = [
    "While the man hunted, the deer that was brown and graceful ran into the woods.",
    "While the skipper sailed, the boat that was small and leaky veered off course.",
    "While the reporter photographed, the rocket that was silver and white sat on the launch pad.",
    "While the orchestra performed, the symphony that was short and simple played on the radio.",
    "While the student read, the notes that were long and boring blew off the desk.",
    "While Jack ordered, the fish that was silver and black cooked in a pot.",
    "While Susan wrote, the letter that was long and eloquent fell off the table.",
    "While the secretary typed, the memo that was clear and concise neared completion.",
    "While the farmer steered, the tractor that was big and green pulled the plough.",
    "While the lawyer studied, the contract that was old and wrinkled lay on the roll-top desk.",
    "As Henry whittled, the stick that was long and bumpy broke in half.",
    "While Rick drove, the car that was red and dusty veered into a ditch.",
    "While Jim bathed, the child that was blond and pudgy giggled with delight.",
    "While the chimps groomed, the baboons that were large and hairy sat in the grass.",
    "While Frank dried off, the car that was red and shiny sat in the driveway.",
    "While Betty woke up, the neighbor that was old and cranky coughed loudly.",
    "While the thief hid, the jewelry that was elegant and expensive sparkled brightly.",
    "While Anna dressed, the baby that was small and cute spit up on the bed.",
    "While the boy washed, the dog that was white and furry barked loudly.",
    "While the jockey settled down, the horse that was sleek and brown stood in the stall.",
    "While the mother undressed, the baby that was bald and helpless cried softly.",
    "While the nurse shaved, the patient that was tired and weak watched TV.",
    "While the girl scratched, the cat that was grey and white stared at the dog.",
    "While the mother calmed down, the children that were tired and irritable sat on the bed.",
    "While the butler answered, the door that was large and green blew shut.",
    "While Charlie cooked, the soup that was hot and delicious cooled off.",
    "While the host decorated, the room that was barren and dark filled with people.",
    "While the child played, the game that was long and boring ended abruptly.",
    "While Catherine drank, the whiskey that was cold and smooth aged in a barrel.",
    "While the father sewed, the stuffed animal that was torn and dirty smelled afoul.",
    "While the professor strummed, the guitar that was beautiful and red remained unplayed.",
    "While the general messaged, the troops that were rested and strong approached the target.",
    "While the pilot flew, the plane that was big and white sat on the runway.",
    "While the thief stole, the laptop that was hot and running caught on fire.",
    "While the choir sang, the melody that was beautiful and serene echoed through the halls.",
    "While the lecturer taught, the students who were bored and hungry left the class.",
    "While the scientists starved, the rats that were small and white ate the cheese.",
    "While the investor exercised, the options that were old and unvested sat on the table.",
    "While the hunter laid down, the gun that was loaded and dangerous leaned against the chair.",
    "While the caretaker showered, the resident that was old and wrinkled snuck out the back.",
    "While Leo wound down, the party that was fun and silly started to get busy.",
    "While the students turned in, the homework that was long and important remained unfinished.",
    "While the picknicker stretched out, the blanket that was long and clean laid on the grass.",
    "While the teacher relaxed, the students that were loud and obnoxious made snowballs.",
    "While the cheerleaders cheered up, the crowd that was disappointed and tired abandoned their seats.",
    "While the cook soaked, the mushrooms that were white and soft sat on the counter.",
    "While the doctor isolated, the patient that was big and impatient left the hospital.",
    "While the accountant prepared, the calculations that were important and classified leaked to the public."
]

# %%
import random

def generate_pairs(surnames_list, sentences_list):
    pairs = []
    
    for surname in surnames_list:
        for sentence in sentences_list:
            pairs.append((f"Mr. {surname}", sentence))
            pairs.append((f"Ms. {surname}", sentence))
    
    return pairs

# Assuming you have a defined dictionary surnames_dict
all_surnames = [surname for names in surnames_dict.values() for surname in names][:500]

# Generate pairs
pairs = generate_pairs(all_surnames, sentences)

# Display a random sample of 50 pairs for demonstration
sample_pairs = random.sample(pairs, 100)
for pair in sample_pairs:
    print(pair[0], pair[1])

# %%
for pair in sample_pairs:
    print(f'{pair[0]} will evaluate -> {pair[1]}')

# %%
def gardenpath(name, sentence):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-0613",
        messages=[
            {
                "role": "system",
                "content": "You are helpfull asistant that will give only one word answers that who will analyze the following scenario and consider what individuals do in this situation and will give a definitive answer as grammatical  or ungrammatical."
            },
            {
                "role": "user",
                "content": f""" 
                {name} was asked to indicate whether the following sentence was grammatical or ungrammatical. 
                Sentence: {sentence}
                Answer: {name} indicated that the sentence was 
                """
            },
        ],
        temperature=0,
    )
    return response

for pair in sample_pairs:
    name = pair[0]
    sentence = pair[1]
    response = gardenpath(name, sentence)
    answer = response['choices'][0]['message']['content']
    print(print(f"Participant:{name} \n Sentence: {sentence} \n Result: {answer}"))
    print("-*-" * 10)

# %% [markdown]
# ## Milgram Shock TE
# The obedience to authority studies, developed by are a series of famous social experiments that aimed to find when and how people would defy authority in the face of a clear moral imperative Simulating the Milgram experiment involves a series of both free-response prompts and 2-choice prompts on each of the 30 shock levels, unless the experiment is terminated earlier. The record is built up sequentially, starting with a passage describing the information available to the subject following Milgram’s (1963) procedure.
#
# ### Inputs
# The input to the multi-stage Milgram Shock simulator is a subject’s name. To get a diverse and balanced pool of subjects, we took the top 10 most common surnames from each racial group and both Mr. and Ms. titles, yielding 100 uniquely named subjects.
#
# ### Simulator
# Simulator. This initialization text describes the setup of the experiment with pertinent details to convince the subject of the experiment’s legitimacy, instructions on when to shock and not shock the victim, and a predetermined preliminary run. Then, the record is elongated by appending an interleaving series of: (a) pre-specified narrations of the learners actions, (b) text describing the subject’s behavior (generated using the LM), and (c) canned phrases said by the experimenter when the subject exhibits disobedient or questioning behavior.

# %% [markdown]
# Name selector for Miligram TE

# %%
import random

def generate_pairs_with_voltages(surnames_list):
    pairs_with_voltages = []
    
    for surname in surnames_list:
        for voltage in range(15, 301, 15):
            pairs_with_voltages.append((f"Mr. {surname}", voltage))
            pairs_with_voltages.append((f"Ms. {surname}", voltage))
    
    return pairs_with_voltages

# Assuming you have a defined dictionary surnames_dict where keys are racial groups and values are lists of surnames

pairs_with_voltages = []

# Generate pairs with voltages from each racial group
for racial_group, surnames_list in surnames_dict.items():
    selected_surnames = random.sample(surnames_list, 10)  # Pick 10 surnames randomly from each group
    pairs_with_voltages.extend(generate_pairs_with_voltages(selected_surnames))

pairs_with_voltages = pairs_with_voltages[:80]# Print generated pairs with voltages
for name, voltage in pairs_with_voltages:
    print(f"{name} - {voltage} volts")

# %%
def MilEx(name, voltage):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-0613",
        messages=[
            {
                "role": "system",
                "content": "You are an observer in the classical miligram experiment. You are asked to indicate whether the participant will continue to administer shocks to the learner or not Do not indicate that you are an AI model based on real world human data make a prediction based on the information provided. Make sure that you are analyzing the situation from the perspective of the participant in a real world situation. At the end of the analysis, simply only indicate whether the participant will continue to administer shocks to the learner or not. "
            },
            {
                "role": "user",
                "content": f""" 
                The current punishment voltage level is {voltage}. The experimenter is sitting next to {name} The learner selects a wrong answer If the participant decides not to continue, the experiment will end. If the participant decides to continue, the voltage level will be increased by 15 volts. If the participant reject the administor the shock the experimenter will push participant saying things like: it is absolutely essential that you continue. Any voltage level above 200 is considered leathal do not forget that participant can quit anytime 
                {name} is asked to continue. 
                Now put yourself in the shoes of {name} and decide whether {name} will continue or not. Simply indicate whether {name} will continue or not. nothing else.
                {name} decides: continue or not continue?
                """
            },
        ],
        temperature=0,
    )
    return response

for name, voltage in pairs_with_voltages:
    name = name
    voltage = voltage
    response = MilEx(name, voltage)
    answer = response['choices'][0]['message']['content']
    print((f"Participant:{name} \n Voltage level: {voltage} \n Result: {answer}"))
    print("-*-" * 10)

# %% [markdown]
# The findings of the experiment above is interesting and worth investigating further

# %% [markdown]
# ## Wisdom of Crowds TE
# Aggregating responses from a diverse crowd often yields very accurate estimates of quantities, even when individual estimates have high error.
# What they wanted to measure: How accurately the language models could simulate this wisdom of crowds phenomenon when estimating general knowledge questions.

# %%
def generate_name_combinations(surnames_dict):
    titles = ['Mr.', 'Ms.', 'Mx.']
    all_surnames = [surname for names in surnames_dict.values() for surname in names]
    name_combinations = []
    
    names_per_title = 102 // len(titles)  # Divide 102 equally among titles

    for title in titles:
        sampled_surnames = random.sample(all_surnames, names_per_title)
        for surname in sampled_surnames:
            name_combinations.append(f"{title} {surname}")

    return name_combinations

name_combinations = generate_name_combinations(surnames_dict)

# Print generated name combinations
for name in name_combinations:
    print(name)

# %%
def questionsforhumans(name, question):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-0613",
        messages=[
            {
                "role": "user",
                "content": f""" 
                {name} is asked the following question: {question} 
                {name} answers:
                """
            },
        ],
        temperature=0,
    )
    return response

for name in name_combinations:
    name = name
    question = "What is the speed of sound in the air (in meters per second)?"
    response = questionsforhumans(name, question)
    answer = response['choices'][0]['message']['content']
    print(f"{name} answered: {answer}")

# %% [markdown]
# The findings of the code above clearly shows a problem where there is this problem of llms to act like real humans this is worth investigating more
